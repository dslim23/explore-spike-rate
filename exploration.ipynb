# %%
data_path = 'N2_200203_johncontrasttrack9_train1_stitched_all_maps.mat'
import scipy.io as sio

# %%
     
trial_starts = data_mat['trialStarts'].flatten()-1

# %%
filter_spike_data(spike_data, trial_idx, neuron=None, block=1, trial=None).shape
# Out:
# (201, 177, 160)

# %%
trial_idx = data_mat['trialStarts'].flatten()-1

# %%
filter_spike_data(spike_data, neuron=3, trial=1).shape
# Out:
# (201, 1, 160)

# %%
spike_data = data_mat['all_maps']

spike_data.shape
# Out:
# (201, 619, 160)

# %%
import matplotlib
import matplotlib.pyplot as plt
norm = matplotlib.colors.Normalize(vmin=None, vmax=None, clip=False)
im = plt.imshow(data_mat['all_maps'][1],norm=norm, interpolation='nearest', aspect='auto')

# %%
(data_mat['all_maps'][2].T**(1/10)).min()
# Out:
# 0.0

# %%
data_mat['all_maps'][2].T.min()
# Out:
# 0.0

# %%
trial_starts = data_mat['trialStarts'].flatten() - 1

# %%
trial_starts
# Out:
# array([  0, 177, 217, 257, 297, 337, 377, 417, 437], dtype=uint16)

# %%
ax = sns.heatmap(data_mat['all_maps'][3,0:177])
